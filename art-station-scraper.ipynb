# %%
import requests
import json
import os
import time
import numpy as np

def pause_report(length, random_delay, file_count, disp = True):
    
    pause_time = length*np.random.normal(1,random_delay)
    if disp: print(f"Downloaded {file_count} files. Pausing scraper for {round(pause_time,2)} seconds.")
    time.sleep(pause_time)

def get_data(query, page_start, page_end, short_pause=3, long_pause=30, random_delay=0.25):

    if page_start < 1:
        print("Starting page number has to be greater than 0.")
        print("Process exiting with error.")
        return 0
    
    if not os.path.exists(f'raw_data/{query}'):
        print(f'Creating directory: raw_data/{query}')
        os.makedirs(f'raw_data/{query}')
        
    saved_files = []
        
    for page_number in range(page_start, page_end):

        url = f"https://www.artstation.com/api/v2/search/projects.json?page={page_number}&per_page=75&query={query}&sorting=relevance"
        
        filename = f'raw_data/{query}/data_{page_number}.json'
            
        # only scrape url if json file of the url doesn't already exist
        if not os.path.exists(filename):
            client = requests.session()
            r = client.get(url)
            print(f"Scraping {url} {r.status_code}: {r.reason}")
            
            # check if rate-limit was exceeded.
            if r.status_code == 429:
                print("Rate-limit exceeded. Wait for a while and try running scraper again.")
                print("Process exiting with error.")
                return 0
            
            # if "data" in response text is empty, the max page has probably been reached.
            data = json.loads(r.text)
            if len(data['data']) == 0:
                print(f"Data list is empty. Query {query} has no data on page {page_number}.")
                print(f"Max page for this query has probably been reached. Ending scraping process.")
                return 0

            # save file
            print(f'Saving file as {filename}')
            with open(filename, 'w', encoding='utf-8') as f:
                json.dump(r.text, f, ensure_ascii=False, indent=4)
                saved_files.append(filename)
                
            # take a short pause per url scraped
            pause_report(short_pause, random_delay, len(saved_files))
        
        else:
            print(f'{filename} already exists. Skipping the current url.')

        # take a long pause if 10 urls have been scraped
        if len(saved_files) > 0 and len(saved_files)%10 == 0:
            pause_report(long_pause, random_delay, len(saved_files))
      
    # process end summary
    print(f"Files saved: {saved_files}")
    print(f"Process finished running.")
    return 1

# %%
genres = ['cyberpunk','noir','horror','western','cartoon','steampunk']

# through trial and error: one scrape 35 pages MAX otherwise 429 error
get_data(genres[2], 100, 200, short_pause=10, long_pause=60)
# Out:
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=100&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_100.json
# Downloaded 1 files. Pausing scraper for 5.85 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=101&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_101.json
# Downloaded 2 files. Pausing scraper for 7.32 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=102&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_102.json
# Downloaded 3 files. Pausing scraper for 9.26 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=103&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_103.json
# Downloaded 4 files. Pausing scraper for 11.96 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=104&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_104.json
# Downloaded 5 files. Pausing scraper for 9.68 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=105&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_105.json
# Downloaded 6 files. Pausing scraper for 12.55 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=106&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_106.json
# Downloaded 7 files. Pausing scraper for 7.13 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=107&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_107.json
# Downloaded 8 files. Pausing scraper for 8.99 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=108&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_108.json
# Downloaded 9 files. Pausing scraper for 10.32 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=109&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_109.json
# Downloaded 10 files. Pausing scraper for 8.84 seconds.
# Downloaded 10 files. Pausing scraper for 57.3 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=110&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_110.json
# Downloaded 11 files. Pausing scraper for 10.52 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=111&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_111.json
# Downloaded 12 files. Pausing scraper for 14.67 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=112&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_112.json
# Downloaded 13 files. Pausing scraper for 11.1 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=113&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_113.json
# Downloaded 14 files. Pausing scraper for 4.23 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=114&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_114.json
# Downloaded 15 files. Pausing scraper for 11.43 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=115&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_115.json
# Downloaded 16 files. Pausing scraper for 8.04 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=116&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_116.json
# Downloaded 17 files. Pausing scraper for 11.46 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=117&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_117.json
# Downloaded 18 files. Pausing scraper for 9.37 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=118&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_118.json
# Downloaded 19 files. Pausing scraper for 9.22 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=119&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_119.json
# Downloaded 20 files. Pausing scraper for 7.12 seconds.
# Downloaded 20 files. Pausing scraper for 88.22 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=120&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_120.json
# Downloaded 21 files. Pausing scraper for 8.85 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=121&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_121.json
# Downloaded 22 files. Pausing scraper for 11.5 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=122&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_122.json
# Downloaded 23 files. Pausing scraper for 8.18 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=123&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_123.json
# Downloaded 24 files. Pausing scraper for 8.34 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=124&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_124.json
# Downloaded 25 files. Pausing scraper for 7.99 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=125&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_125.json
# Downloaded 26 files. Pausing scraper for 12.11 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=126&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_126.json
# Downloaded 27 files. Pausing scraper for 5.79 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=127&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_127.json
# Downloaded 28 files. Pausing scraper for 11.58 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=128&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_128.json
# Downloaded 29 files. Pausing scraper for 7.79 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=129&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_129.json
# Downloaded 30 files. Pausing scraper for 9.59 seconds.
# Downloaded 30 files. Pausing scraper for 34.89 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=130&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_130.json
# Downloaded 31 files. Pausing scraper for 10.85 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=131&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_131.json
# Downloaded 32 files. Pausing scraper for 13.38 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=132&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_132.json
# Downloaded 33 files. Pausing scraper for 8.82 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=133&per_page=75&query=horror&sorting=relevance 200: OK
# Saving file as raw_data/horror/data_133.json
# Downloaded 34 files. Pausing scraper for 10.33 seconds.
# Scraping https://www.artstation.com/api/v2/search/projects.json?page=134&per_page=75&query=horror&sorting=relevance 200: OK
# Data list is empty. Query horror has no data on page 134.
# Max page for this query has probably been reached. Ending scraping process.
# 0
